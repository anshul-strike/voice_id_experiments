# %%
from openai import OpenAI

# %%
client = OpenAI(api_key = "")

# %%
# !pwd
# Out:
# /Users/anshulchiranth/Desktop/Strike/Voice Experiments

# %%
audio_file = open("Sample Transactions/0eb14637-7e73-4ae6-bc48-0faa29e43141.wav", "rb")

# %%
transcription = client.audio.transcriptions.create(model = "gpt-4o-transcribe", file = audio_file, response_format = "text")
print(transcription)
# Out:
# So wonderful day at Dairy Queen, how can we make it yours?
#
# Yes, can I get a... can I get a small strawberry sundae with extra strawberries?
#
# Small strawberry sundae with extra strawberries, anything else for you?
#
# That's it.
#
# Your total is $4.69.
#
# Oh, you want a monkey? I'm sorry, can I add something?
#
# I'm sorry?
#
# Can I add something?
#
# Yes, what can I get for you?
#
# Can I get a mini banana split blizzard? And that strawberry sundae, can you make it a large?

# %%
STEP1_SYSTEM_PROMPT = """You are a transcript processor for drive-thru audio recordings. Your job is to:

1. Add speaker labels ("Operator:" and "Customer:") to each line of the transcript
2. Extract metadata about the transaction

For each transcript, return a JSON object with these fields:

{
    "text": "The full transcript with Operator: and Customer: labels on each line",
    "complete_order": 1 if the order appears complete, 0 if garbled/incoherent/missing items/mostly non-English,
    "mobile_order": 1 if customer is picking up a mobile/online order, 0 otherwise,
    "coupon_used": 1 if a coupon was mentioned or applied, 0 otherwise,
    "asked_more_time": 1 if the operator asked the customer to wait/hold on, 0 otherwise,
    "out_of_stock_items": "comma-separated list of out-of-stock items mentioned" or "0" if none
}

Rules:
- Preserve the exact wording of the transcript
- Each line should start with either "Operator: " or "Customer: "
- If you can't determine who is speaking, make your best guess based on context
- An order is incomplete if it's mostly unintelligible, missing key items, or primarily non-English
- Mobile orders are when customers mention picking up an online/app order
- Only mark coupon_used=1 if a coupon/discount is explicitly mentioned
- asked_more_time=1 if operator says things like "hold on", "one moment", "give me a second"
"""

# %%
final_step1_prompt = f"""{STEP1_SYSTEM_PROMPT}

Process this transcript and return the JSON result:

---
{transcription}
---

Return ONLY the JSON object, no other text."""

# %%
final_step1_prompt
# Out:
# 'You are a transcript processor for drive-thru audio recordings. Your job is to:\n\n1. Add speaker labels ("Operator:" and "Customer:") to each line of the transcript\n2. Extract metadata about the transaction\n\nFor each transcript, return a JSON object with these fields:\n\n{\n    "text": "The full transcript with Operator: and Customer: labels on each line",\n    "complete_order": 1 if the order appears complete, 0 if garbled/incoherent/missing items/mostly non-English,\n    "mobile_order": 1 if customer is picking up a mobile/online order, 0 otherwise,\n    "coupon_used": 1 if a coupon was mentioned or applied, 0 otherwise,\n    "asked_more_time": 1 if the operator asked the customer to wait/hold on, 0 otherwise,\n    "out_of_stock_items": "comma-separated list of out-of-stock items mentioned" or "0" if none\n}\n\nRules:\n- Preserve the exact wording of the transcript\n- Each line should start with either "Operator: " or "Customer: "\n- If you can\'t determine who is speaking, make your best guess based on context\n- An order is incomplete if it\'s mostly unintelligible, missing key items, or primarily non-English\n- Mobile orders are when customers mention picking up an online/app order\n- Only mark coupon_used=1 if a coupon/discount is explicitly mentioned\n- asked_more_time=1 if operator says things like "hold on", "one moment", "give me a second"\n\n\nProcess this transcript and return the JSON result:\n\n---\nSo wonderful day at Dairy Queen, how can we make it yours?\n\nYes, can I get a... can I get a small strawberry sundae with extra strawberries? \n\nSmall strawberry sundae with extra strawberries, anything else for you?\n\nThat\'s it.\n\nYour total is $4.69.\n\nOh, you want a monkey? I\'m sorry, can I add something?\n\nI\'m sorry?\n\nCan I add something?\n\nYes, what can I get for you?\n\nCan I get a mini banana split blizzard? And that strawberry sundae, can you make it a large?\n\n---\n\nReturn ONLY the JSON object, no other text.'

# %%
messages = messages = [{"role": "user", "content": final_step1_prompt}]
kwargs = {
            "model": "gpt-4o",
            "messages": messages,
            "temperature": 0,
        }

# %%
response = client.chat.completions.create(**kwargs)

# %%
response.choices[0].message.content
# Out:
# '```json\n{\n    "text": "Operator: So wonderful day at Dairy Queen, how can we make it yours?\\nCustomer: Yes, can I get a... can I get a small strawberry sundae with extra strawberries?\\nOperator: Small strawberry sundae with extra strawberries, anything else for you?\\nCustomer: That\'s it.\\nOperator: Your total is $4.69.\\nCustomer: Oh, you want a monkey? I\'m sorry, can I add something?\\nOperator: I\'m sorry?\\nCustomer: Can I add something?\\nOperator: Yes, what can I get for you?\\nCustomer: Can I get a mini banana split blizzard? And that strawberry sundae, can you make it a large?",\n    "complete_order": 1,\n    "mobile_order": 0,\n    "coupon_used": 0,\n    "asked_more_time": 0,\n    "out_of_stock_items": "0"\n}\n```'

# %%
raw_content = response.choices[0].message.content
cleaned = raw_content.strip("```json").strip("```").strip()
cleaned
# Out:
# '{\n    "text": "Operator: So wonderful day at Dairy Queen, how can we make it yours?\\nCustomer: Yes, can I get a... can I get a small strawberry sundae with extra strawberries?\\nOperator: Small strawberry sundae with extra strawberries, anything else for you?\\nCustomer: That\'s it.\\nOperator: Your total is $4.69.\\nCustomer: Oh, you want a monkey? I\'m sorry, can I add something?\\nOperator: I\'m sorry?\\nCustomer: Can I add something?\\nOperator: Yes, what can I get for you?\\nCustomer: Can I get a mini banana split blizzard? And that strawberry sundae, can you make it a large?",\n    "complete_order": 1,\n    "mobile_order": 0,\n    "coupon_used": 0,\n    "asked_more_time": 0,\n    "out_of_stock_items": "0"\n}'

# %%
import json

data = json.loads(cleaned)

# Keep only what you want
filtered = {
    "text": data["text"],
}

print(filtered)
# Out:
# {'text': "Operator: So wonderful day at Dairy Queen, how can we make it yours?\nCustomer: Yes, can I get a... can I get a small strawberry sundae with extra strawberries?\nOperator: Small strawberry sundae with extra strawberries, anything else for you?\nCustomer: That's it.\nOperator: Your total is $4.69.\nCustomer: Oh, you want a monkey? I'm sorry, can I add something?\nOperator: I'm sorry?\nCustomer: Can I add something?\nOperator: Yes, what can I get for you?\nCustomer: Can I get a mini banana split blizzard? And that strawberry sundae, can you make it a large?"}

# %%
#This is step1 transcript
filtered["text"]
# Out:
# "Operator: So wonderful day at Dairy Queen, how can we make it yours?\nCustomer: Yes, can I get a... can I get a small strawberry sundae with extra strawberries?\nOperator: Small strawberry sundae with extra strawberries, anything else for you?\nCustomer: That's it.\nOperator: Your total is $4.69.\nCustomer: Oh, you want a monkey? I'm sorry, can I add something?\nOperator: I'm sorry?\nCustomer: Can I add something?\nOperator: Yes, what can I get for you?\nCustomer: Can I get a mini banana split blizzard? And that strawberry sundae, can you make it a large?"

# %%
import stable_whisper

# %%
model = stable_whisper.load_model("base")
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:06<00:00, 23.3MiB/s]

# %%
result = model.align("Sample Transactions/0eb14637-7e73-4ae6-bc48-0faa29e43141.wav", transcription, language = "en")
# Out:
# Align: 100%|██████████| 47.06/47.06 [00:01<00:00, 40.76sec/s]
# /opt/anaconda3/envs/voice_id_env/lib/python3.11/site-packages/stable_whisper/alignment.py:211: UserWarning: Failed to align the last 2/86 words after 00:46.500.
#   result = aligner.align(audio, text)
# Adjustment: 100%|██████████| 47.06/47.06 [00:00<00:00, 53549.63sec/s]
# /opt/anaconda3/envs/voice_id_env/lib/python3.11/site-packages/stable_whisper/alignment.py:211: UserWarning: 2/18 segments failed to align.
#   result = aligner.align(audio, text)

# %%
import os
os.environ["PATH"] += os.pathsep + "/opt/homebrew/bin"

# %%
result

# %%
result.to_srt_vtt("audio_2.srt")
# Out:
# Saved: /Users/anshulchiranth/Desktop/Strike/Voice Experiments/audio_2.srt
